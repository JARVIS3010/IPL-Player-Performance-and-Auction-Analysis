# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # **Unitialising The URL**

# %%
import pandas as pd

# %%
url="https://www.news18.com/ipl-auction/"

# %%
initial=pd.read_html(url)

# %%
type(initial)
# Out:
# list

# %% [markdown]
# # 1.Creating Dataframe of Gujarat Titans

# %%
initial[1]
# Out:
#          2024 Squad GT Base Price          TYPE  COST IN ₹ (CR.)  \
# 0      Spencer Johnson    5000000        BOWLER             10.0
# 1        Shahrukh Khan    4000000   ALL-ROUNDER              7.4
# 2          Umesh Yadav   20000000        BOWLER              5.8
# 3           Robin Minz    2000000  WICKETKEEPER              3.6
# 4       Sushant Mishra    2000000        BOWLER              2.2
# 5         Kartik Tyagi    2000000        BOWLER              0.6
# 6   Azmatullah Omarzai    5000000   ALL-ROUNDER              0.5
# 7         Manav Suthar    2000000        BOWLER              0.2
# 8         David Miller   Retained           NaN              0.0
# 9         Shubman Gill   Retained           NaN              0.0
# 10        Matthew Wade   Retained           NaN              0.0
# 11     Wriddhiman Saha   Retained           NaN              0.0
# 12     Kane Williamson   Retained           NaN              0.0
# ...

# %%
gujarat_titans=initial[1]

# %%
gujarat_titans["Team"]="Gujarat Titans"

# %%
gujarat_titans.rename(columns={"2024 Squad GT":"Player"},inplace=True)

# %%
gujarat_titans
# Out:
#                 Player Base Price          TYPE  COST IN ₹ (CR.)  \
# 0      Spencer Johnson    5000000        BOWLER             10.0
# 1        Shahrukh Khan    4000000   ALL-ROUNDER              7.4
# 2          Umesh Yadav   20000000        BOWLER              5.8
# 3           Robin Minz    2000000  WICKETKEEPER              3.6
# 4       Sushant Mishra    2000000        BOWLER              2.2
# 5         Kartik Tyagi    2000000        BOWLER              0.6
# 6   Azmatullah Omarzai    5000000   ALL-ROUNDER              0.5
# 7         Manav Suthar    2000000        BOWLER              0.2
# 8         David Miller   Retained           NaN              0.0
# 9         Shubman Gill   Retained           NaN              0.0
# 10        Matthew Wade   Retained           NaN              0.0
# 11     Wriddhiman Saha   Retained           NaN              0.0
# 12     Kane Williamson   Retained           NaN              0.0
# ...

# %% [markdown]
# # 2.Creating Dataframe of Chennai Super Kings

# %%
initial[2]
# Out:
#             2024 Squad CSK Base Price          TYPE  COST IN ₹ (CR.)  \
# 0           Daryl Mitchell   10000000   ALL-ROUNDER             14.0
# 1             Sameer Rizvi    2000000        BATTER              8.4
# 2           Shardul Thakur   20000000   ALL-ROUNDER              4.0
# 3        Mustafizur Rahman   20000000        BOWLER              2.0
# 4          Rachin Ravindra    5000000   ALL-ROUNDER              1.8
# 5     Avanish Rao Aravelly    2000000  WICKETKEEPER              0.2
# 6                 MS Dhoni   Retained           NaN              0.0
# 7                Moeen Ali   Retained           NaN              0.0
# 8            Deepak Chahar   Retained           NaN              0.0
# 9             Devon Conway   Retained           NaN              0.0
# 10        Tushar Deshpande   Retained           NaN              0.0
# 11             Shivam Dube   Retained           NaN              0.0
# 12         Ruturaj Gaikwad   Retained           NaN              0.0
# ...

# %%
csk=initial[2]
csk["Team"]="Chennai Super Kings"
csk.rename(columns={"2024 Squad CSK":"Player"},inplace=True)
#Appending into first Dataframe
final=gujarat_titans._append(csk,ignore_index=True)
final
# Out:
#                     Player Base Price          TYPE  COST IN ₹ (CR.)  \
# 0          Spencer Johnson    5000000        BOWLER             10.0
# 1            Shahrukh Khan    4000000   ALL-ROUNDER              7.4
# 2              Umesh Yadav   20000000        BOWLER              5.8
# 3               Robin Minz    2000000  WICKETKEEPER              3.6
# 4           Sushant Mishra    2000000        BOWLER              2.2
# 5             Kartik Tyagi    2000000        BOWLER              0.6
# 6       Azmatullah Omarzai    5000000   ALL-ROUNDER              0.5
# 7             Manav Suthar    2000000        BOWLER              0.2
# 8             David Miller   Retained           NaN              0.0
# 9             Shubman Gill   Retained           NaN              0.0
# 10            Matthew Wade   Retained           NaN              0.0
# 11         Wriddhiman Saha   Retained           NaN              0.0
# 12         Kane Williamson   Retained           NaN              0.0
# ...

# %% [markdown]
# # 3.Creating Dataframe of Delhi Capital

# %%
initial[3]
# Out:
#        2024 Squad DC Base Price          TYPE  COST IN ₹ (CR.)  \
# 0     Kumar Kushagra    2000000  WICKETKEEPER             7.20
# 1    Jhye Richardson   15000000        BOWLER             5.00
# 2        Harry Brook   20000000        BATTER             4.00
# 3        Sumit Kumar    2000000   ALL-ROUNDER             1.00
# 4          Shai Hope    7500000  WICKETKEEPER             0.75
# 5     Tristan Stubbs    5000000  WICKETKEEPER             0.50
# 6         Ricky Bhui    2000000  WICKETKEEPER             0.20
# 7         Rasikh Dar    2000000        BOWLER             0.20
# 8   Swastik Chhikara    2000000        BATTER             0.20
# 9       Rishabh Pant   Retained           NaN             0.00
# 10      Pravin Dubey   Retained           NaN             0.00
# 11      David Warner   Retained           NaN             0.00
# 12      Vicky Ostwal   Retained           NaN             0.00
# 13      Prithvi Shaw   Retained           NaN             0.00
# ...

# %%
DC=initial[3]
DC["Team"]="Delhi Capital"
DC.rename(columns={"2024 Squad DC":"Player"},inplace=True)
#Appending into previous Dataframe
final=final._append(DC,ignore_index=True)
final
# Out:
#              Player Base Price          TYPE  COST IN ₹ (CR.)  \
# 0   Spencer Johnson    5000000        BOWLER             10.0
# 1     Shahrukh Khan    4000000   ALL-ROUNDER              7.4
# 2       Umesh Yadav   20000000        BOWLER              5.8
# 3        Robin Minz    2000000  WICKETKEEPER              3.6
# 4    Sushant Mishra    2000000        BOWLER              2.2
# ..              ...        ...           ...              ...
# 70    Khaleel Ahmed   Retained           NaN              0.0
# 71   Mitchell Marsh   Retained           NaN              0.0
# 72    Ishant Sharma   Retained           NaN              0.0
# 73       Yash Dhull   Retained           NaN              0.0
# 74     Mukesh Kumar   Retained           NaN              0.0
#
#     Cost IN $ (000) 2023 Squad            Team
# 0              1200        NaN  Gujarat Titans
# 1               888       PBKS  Gujarat Titans
# 2               696        KKR  Gujarat Titans
# ...

# %% [markdown]
# # 4.Creating Dataframe of Kolkata Knight Riders

# %%
initial[4]
# Out:
#           2024 Squad KKR Base Price          TYPE  COST IN ₹ (CR.)  \
# 0         Mitchell Starc   20000000        BOWLER            24.75
# 1          Mujeeb Rahman   20000000        BOWLER             2.00
# 2    Sherfane Rutherford   15000000        BATTER             1.50
# 3           Gus Atkinson   10000000        BOWLER             1.00
# 4          Manish Pandey    5000000        BATTER             0.50
# 5            K.S. Bharat    5000000  WICKETKEEPER             0.50
# 6        Chetan Sakariya    5000000        BOWLER             0.50
# 7   Angkrish Raghuvanshi    2000000        BATTER             0.20
# 8        Ramandeep Singh    2000000   ALL-ROUNDER             0.20
# 9          Sakib Hussain    2000000        BOWLER             0.20
# 10           Nitish Rana   Retained           NaN             0.00
# 11           Rinku Singh   Retained           NaN             0.00
# 12    Rahmanullah Gurbaz   Retained           NaN             0.00
# ...

# %%
KKR=initial[4]
KKR["Team"]="Kolkata Knight Riders"
KKR.rename(columns={"2024 Squad KKR":"Player"},inplace=True)
#Appending into previous Dataframe
final=final._append(KKR,ignore_index=True)
final
# Out:
#                  Player Base Price          TYPE  COST IN ₹ (CR.)  \
# 0       Spencer Johnson    5000000        BOWLER             10.0
# 1         Shahrukh Khan    4000000   ALL-ROUNDER              7.4
# 2           Umesh Yadav   20000000        BOWLER              5.8
# 3            Robin Minz    2000000  WICKETKEEPER              3.6
# 4        Sushant Mishra    2000000        BOWLER              2.2
# ..                  ...        ...           ...              ...
# 93        Andre Russell   Retained           NaN              0.0
# 94       Venkatesh Iyer   Retained           NaN              0.0
# 95         Harshit Rana   Retained           NaN              0.0
# 96        Vaibhav Arora   Retained           NaN              0.0
# 97  Varun Chakaravarthy   Retained           NaN              0.0
#
#     Cost IN $ (000) 2023 Squad                   Team
# 0              1200        NaN         Gujarat Titans
# 1               888       PBKS         Gujarat Titans
# ...

# %% [markdown]
# # 5.Creating Dataframe of Punjab Kings

# %%
initial[5]
# Out:
#             2024 Squad PBKS Base Price         TYPE  COST IN ₹ (CR.)  \
# 0             Harshal Patel   20000000  ALL-ROUNDER            11.75
# 1             Rilee Rossouw   20000000       BATTER             8.00
# 2              Chris Woakes   20000000  ALL-ROUNDER             4.20
# 3           Ashutosh Sharma    2000000  ALL-ROUNDER             0.20
# 4   Vishwanath Pratap Singh    2000000  ALL-ROUNDER             0.20
# 5            Shashank Singh    2000000  ALL-ROUNDER             0.20
# 6        Tanay Thyagarajann    2000000  ALL-ROUNDER             0.20
# 7          Prince Choudhary    2000000       BOWLER             0.20
# 8            Shikhar Dhawan   Retained          NaN             0.00
# 9          Liam Livingstone   Retained          NaN             0.00
# 10           Jonny Bairstow   Retained          NaN             0.00
# 11       Gurnoor Singh Brar   Retained          NaN             0.00
# 12            Jitesh Sharma   Retained          NaN             0.00
# ...

# %%
PBKS=initial[5]
PBKS["Team"]="Punjab Kings"
PBKS.rename(columns={"2024 Squad PBKS":"Player"},inplace=True)
#Appending into previous Dataframe
final=final._append(PBKS,ignore_index=True)
final
# Out:
#               Player Base Price          TYPE  COST IN ₹ (CR.)  \
# 0    Spencer Johnson    5000000        BOWLER             10.0
# 1      Shahrukh Khan    4000000   ALL-ROUNDER              7.4
# 2        Umesh Yadav   20000000        BOWLER              5.8
# 3         Robin Minz    2000000  WICKETKEEPER              3.6
# 4     Sushant Mishra    2000000        BOWLER              2.2
# ..               ...        ...           ...              ...
# 120     Rishi Dhawan   Retained           NaN              0.0
# 121    Kagiso Rabada   Retained           NaN              0.0
# 122       Sam Curran   Retained           NaN              0.0
# 123     Nathan Ellis   Retained           NaN              0.0
# 124    Sikandar Raza   Retained           NaN              0.0
#
#      Cost IN $ (000) 2023 Squad            Team
# 0               1200        NaN  Gujarat Titans
# 1                888       PBKS  Gujarat Titans
# 2                696        KKR  Gujarat Titans
# ...

# %% [markdown]
# # 6.Creating Dataframe of Lucknow Super Giants

# %%
initial[6]
# Out:
#        2024 Squad LSG Base Price         TYPE  COST IN ₹ (CR.)  \
# 0    Devdutt Padikkal     Traded          NaN              NaN
# 1         Shivam Mavi    5000000       BOWLER              6.4
# 2        M. Siddharth    2000000       BOWLER              2.4
# 3        David Willey   20000000  ALL-ROUNDER              2.0
# 4       Ashton Turner   10000000       BATTER              1.0
# 5   Mohd. Arshad Khan    2000000  ALL-ROUNDER              0.2
# 6     Arshin Kulkarni    2000000  ALL-ROUNDER              0.2
# 7            KL Rahul   Retained          NaN              0.0
# 8     Quinton de Kock   Retained          NaN              0.0
# 9     Nicholas Pooran   Retained          NaN              0.0
# 10       Ayush Badoni   Retained          NaN              0.0
# 11        Kyle Mayers   Retained          NaN              0.0
# 12     Marcus Stoinis   Retained          NaN              0.0
# 13       Deepak Hooda   Retained          NaN              0.0
# ...

# %%
LSG=initial[6]
LSG["Team"]="Lucknow Super Giants"
LSG.rename(columns={"2024 Squad LSG":"Player"},inplace=True)
#Appending into previous Dataframe
final=final._append(LSG,ignore_index=True)
final
# Out:
#               Player Base Price          TYPE  COST IN ₹ (CR.)  \
# 0    Spencer Johnson    5000000        BOWLER             10.0
# 1      Shahrukh Khan    4000000   ALL-ROUNDER              7.4
# 2        Umesh Yadav   20000000        BOWLER              5.8
# 3         Robin Minz    2000000  WICKETKEEPER              3.6
# 4     Sushant Mishra    2000000        BOWLER              2.2
# ..               ...        ...           ...              ...
# 144      Yash Thakur   Retained           NaN              0.0
# 145      Amit Mishra   Retained           NaN              0.0
# 146        Mark Wood   Retained           NaN              0.0
# 147     Mayank Yadav   Retained           NaN              0.0
# 148      Mohsin Khan   Retained           NaN              0.0
#
#      Cost IN $ (000) 2023 Squad                  Team
# 0             1200.0        NaN        Gujarat Titans
# 1              888.0       PBKS        Gujarat Titans
# ...

# %% [markdown]
# # 7.Creating Dataframe of Mumbai Indians

# %%
initial[7]
# Out:
#          2024 Squad MI Base Price         TYPE  COST IN ₹ (CR.)  \
# 0        Hardik Pandya     Traded          NaN              NaN
# 1     Romario Shepherd     Traded          NaN              NaN
# 2       Gerald Coetzee   20000000  ALL-ROUNDER              5.0
# 3       Nuwan Thushara    5000000       BOWLER              4.8
# 4        Mohammad Nabi   15000000  ALL-ROUNDER              1.5
# 5        Shreyas Gopal    2000000       BOWLER              0.2
# 6           Naman Dhir    2000000  ALL-ROUNDER              0.2
# 7        Anshul Kamboj    2000000  ALL-ROUNDER              0.2
# 8      Shivalik Sharma    2000000  ALL-ROUNDER              0.2
# 9   Dilshan Madushanka    5000000       BOWLER              4.6
# 10        Rohit Sharma   Retained          NaN              0.0
# 11       Dewald Brevis   Retained          NaN              0.0
# 12    Suryakumar Yadav   Retained          NaN              0.0
# 13        Ishan Kishan   Retained          NaN              0.0
# ...

# %%
MI=initial[7]
MI["Team"]="Mumbai Indians"
MI.rename(columns={"2024 Squad MI":"Player"},inplace=True)
#Appending into previous Dataframe
final=final._append(MI,ignore_index=True)
final
# Out:
#                 Player Base Price          TYPE  COST IN ₹ (CR.)  \
# 0      Spencer Johnson    5000000        BOWLER             10.0
# 1        Shahrukh Khan    4000000   ALL-ROUNDER              7.4
# 2          Umesh Yadav   20000000        BOWLER              5.8
# 3           Robin Minz    2000000  WICKETKEEPER              3.6
# 4       Sushant Mishra    2000000        BOWLER              2.2
# ..                 ...        ...           ...              ...
# 170     Jasprit Bumrah   Retained           NaN              0.0
# 171    Kumar Kartikeya   Retained           NaN              0.0
# 172      Piyush Chawla   Retained           NaN              0.0
# 173      Akash Madhwal   Retained           NaN              0.0
# 174  Jason Behrendorff   Retained           NaN              0.0
#
#      Cost IN $ (000) 2023 Squad            Team
# 0             1200.0        NaN  Gujarat Titans
# 1              888.0       PBKS  Gujarat Titans
# ...

# %% [markdown]
# # 8.Creating Dataframe of Royal Challengers Bengaluru

# %%
initial[8]
# Out:
#          2024 Squad RCB Base Price         TYPE  COST IN ₹ (CR.)  \
# 0          Mayank Dagar     Traded          NaN              NaN
# 1         Cameron Green     Traded          NaN              NaN
# 2        Alzarri Joseph   10000000       BOWLER             11.5
# 3            Yash Dayal    2000000       BOWLER              5.0
# 4       Lockie Ferguson   20000000       BOWLER              2.0
# 5            Tom Curran   15000000  ALL-ROUNDER              1.5
# 6        Saurav Chuahan    2000000       BATTER              0.2
# 7         Swapnil Singh    2000000  ALL-ROUNDER              0.2
# 8        Faf du Plessis   Retained          NaN              0.0
# 9         Glenn Maxwell   Retained          NaN              0.0
# 10          Virat Kohli   Retained          NaN              0.0
# 11        Rajat Patidar   Retained          NaN              0.0
# 12           Anuj Rawat   Retained          NaN              0.0
# ...

# %%
RCB=initial[8]
RCB["Team"]="Royal Challengers Bengaluru"
RCB.rename(columns={"2024 Squad RCB":"Player"},inplace=True)
#Appending into previous Dataframe
final=final._append(RCB,ignore_index=True)
final
# Out:
#               Player Base Price          TYPE  COST IN ₹ (CR.)  \
# 0    Spencer Johnson    5000000        BOWLER             10.0
# 1      Shahrukh Khan    4000000   ALL-ROUNDER              7.4
# 2        Umesh Yadav   20000000        BOWLER              5.8
# 3         Robin Minz    2000000  WICKETKEEPER              3.6
# 4     Sushant Mishra    2000000        BOWLER              2.2
# ..               ...        ...           ...              ...
# 195       Akash Deep   Retained           NaN              0.0
# 196   Mohammed Siraj   Retained           NaN              0.0
# 197     Reece Topley   Retained           NaN              0.0
# 198  Himanshu Sharma   Retained           NaN              0.0
# 199      Rajan Kumar   Retained           NaN              0.0
#
#      Cost IN $ (000) 2023 Squad                         Team
# 0             1200.0        NaN               Gujarat Titans
# 1              888.0       PBKS               Gujarat Titans
# ...

# %% [markdown]
# # 9.Creating Dataframe of Rajasthan Royals

# %%
initial[9]
# Out:
#           2024 Squad RR Base Price          TYPE  COST IN ₹ (CR.)  \
# 0            Avesh Khan     Traded           NaN              NaN
# 1         Rovman Powell   10000000        BATTER              7.4
# 2         Shubham Dubey    2000000        BATTER              5.8
# 3         Nandre Burger    5000000        BOWLER              0.5
# 4    Tom Kohler-Cadmore    4000000  WICKETKEEPER              0.4
# 5          Abid Mushtaq    2000000   ALL-ROUNDER              0.2
# 6          Sanju Samson   Retained           NaN              0.0
# 7           Jos Buttler   Retained           NaN              0.0
# 8       Shimron Hetmyer   Retained           NaN              0.0
# 9      Yashasvi Jaiswal   Retained           NaN              0.0
# 10          Dhruv Jurel   Retained           NaN              0.0
# 11          Riyan Parag   Retained           NaN              0.0
# 12     Donovan Ferreira   Retained           NaN              0.0
# ...

# %%
RR=initial[9]
RR["Team"]="Rajasthan Royals"
RR.rename(columns={"2024 Squad RR":"Player"},inplace=True)
#Appending into previous Dataframe
final=final._append(RR,ignore_index=True)
final
# Out:
#                Player Base Price          TYPE  COST IN ₹ (CR.)  \
# 0     Spencer Johnson    5000000        BOWLER             10.0
# 1       Shahrukh Khan    4000000   ALL-ROUNDER              7.4
# 2         Umesh Yadav   20000000        BOWLER              5.8
# 3          Robin Minz    2000000  WICKETKEEPER              3.6
# 4      Sushant Mishra    2000000        BOWLER              2.2
# ..                ...        ...           ...              ...
# 217   Prasidh Krishna   Retained           NaN              0.0
# 218    Sandeep Sharma   Retained           NaN              0.0
# 219       Trent Boult   Retained           NaN              0.0
# 220  Yuzvendra Chahal   Retained           NaN              0.0
# 221        Adam Zampa   Retained           NaN              0.0
#
#      Cost IN $ (000) 2023 Squad              Team
# 0             1200.0        NaN    Gujarat Titans
# 1              888.0       PBKS    Gujarat Titans
# ...

# %% [markdown]
# # 10.Creating Dataframe of Sunrisers Hyderabad

# %%
initial[10]
# Out:
#             2024 Squad SRH Base Price         TYPE  COST IN ₹ (CR.)  \
# 0            Shahbaz Ahmed     Traded          NaN              NaN
# 1              Pat Cummins   20000000  ALL-ROUNDER             20.5
# 2              Travis Head   20000000       BATTER              6.8
# 3           Jaydev Unadkat    5000000       BOWLER              1.6
# 4        Wanindu Hasaranga   15000000  ALL-ROUNDER              1.5
# 5              Akash Singh    2000000       BOWLER              0.2
# 6   Jhathavedh Subramanyan    2000000       BOWLER              0.2
# 7              Abdul Samad   Retained          NaN              0.0
# 8            Aiden Markram   Retained          NaN              0.0
# 9           Rahul Tripathi   Retained          NaN              0.0
# 10          Glenn Phillips   Retained          NaN              0.0
# 11        Heinrich Klaasen   Retained          NaN              0.0
# 12          Mayank Agarwal   Retained          NaN              0.0
# ...

# %%
SRH=initial[10]
SRH["Team"]="Sunrisers Hyderabad"
SRH.rename(columns={"2024 Squad SRH":"Player"},inplace=True)
#Appending into previous Dataframe
final=final._append(SRH,ignore_index=True)
final
# Out:
#                 Player Base Price          TYPE  COST IN ₹ (CR.)  \
# 0      Spencer Johnson    5000000        BOWLER             10.0
# 1        Shahrukh Khan    4000000   ALL-ROUNDER              7.4
# 2          Umesh Yadav   20000000        BOWLER              5.8
# 3           Robin Minz    2000000  WICKETKEEPER              3.6
# 4       Sushant Mishra    2000000        BOWLER              2.2
# ..                 ...        ...           ...              ...
# 242  Bhuvneshwar Kumar   Retained           NaN              0.0
# 243        T Natarajan   Retained           NaN              0.0
# 244    Mayank Markande   Retained           NaN              0.0
# 245        Umran Malik   Retained           NaN              0.0
# 246   Fazalhaq Farooqi   Retained           NaN              0.0
#
#      Cost IN $ (000) 2023 Squad                 Team
# 0             1200.0        NaN       Gujarat Titans
# 1              888.0       PBKS       Gujarat Titans
# ...

# %% [markdown]
# # Adding Information of Unsold players

# %%
initial[11]
# Out:
#                 Players          TYPE Base Price IN ₹ Base Price IN $  \
# 0            Karun Nair        BATTER         5000000           60000
# 1           Steve Smith        BATTER        20000000          240000
# 2           Josh Inglis  WICKETKEEPER        20000000          240000
# 3          Kusal Mendis  WICKETKEEPER         5000000           60000
# 4           Philip Salt  WICKETKEEPER        15000000          180000
# ..                  ...           ...             ...             ...
# 423    Mitchell Santner           NaN        Retained        Retained
# 424     Simarjeet Singh           NaN        Retained        Retained
# 425      Nishant Sindhu           NaN        Retained        Retained
# 426    Prashant Solanki           NaN        Retained        Retained
# 427  Maheesh Theekshana           NaN        Retained        Retained
#
#     2023 Squad
# 0          LSG
# 1          NaN
# 2          NaN
# 3          NaN
# 4           DC
# ..         ...
# ...

# %%
test=initial[11]

# %%
test.rename(columns={"Players":"Player"},inplace=True)

# %%
test.rename(columns={"Base Price IN ₹":"Base Price"},inplace=True)

# %%
test["Team"]="Unsold"
test["COST IN ₹ (CR.)"]="NaN"
test["Cost IN $ (000)"]="NaN"
test.drop("Base Price IN $",axis=1,inplace=True)

# %%
test
# Out:
#                  Player          TYPE Base Price 2023 Squad    Team  \
# 0            Karun Nair        BATTER    5000000        LSG  Unsold
# 1           Steve Smith        BATTER   20000000        NaN  Unsold
# 2           Josh Inglis  WICKETKEEPER   20000000        NaN  Unsold
# 3          Kusal Mendis  WICKETKEEPER    5000000        NaN  Unsold
# 4           Philip Salt  WICKETKEEPER   15000000         DC  Unsold
# ..                  ...           ...        ...        ...     ...
# 423    Mitchell Santner           NaN   Retained        NaN  Unsold
# 424     Simarjeet Singh           NaN   Retained        NaN  Unsold
# 425      Nishant Sindhu           NaN   Retained        NaN  Unsold
# 426    Prashant Solanki           NaN   Retained        NaN  Unsold
# 427  Maheesh Theekshana           NaN   Retained        NaN  Unsold
#
#     COST IN ₹ (CR.) Cost IN $ (000)
# 0               NaN             NaN
# 1               NaN             NaN
# 2               NaN             NaN
# ...

# %%
final=final._append(test,ignore_index=True)
final
# Out:
#                  Player Base Price          TYPE COST IN ₹ (CR.)  \
# 0       Spencer Johnson    5000000        BOWLER            10.0
# 1         Shahrukh Khan    4000000   ALL-ROUNDER             7.4
# 2           Umesh Yadav   20000000        BOWLER             5.8
# 3            Robin Minz    2000000  WICKETKEEPER             3.6
# 4        Sushant Mishra    2000000        BOWLER             2.2
# ..                  ...        ...           ...             ...
# 670    Mitchell Santner   Retained           NaN             NaN
# 671     Simarjeet Singh   Retained           NaN             NaN
# 672      Nishant Sindhu   Retained           NaN             NaN
# 673    Prashant Solanki   Retained           NaN             NaN
# 674  Maheesh Theekshana   Retained           NaN             NaN
#
#     Cost IN $ (000) 2023 Squad            Team
# 0            1200.0        NaN  Gujarat Titans
# 1             888.0       PBKS  Gujarat Titans
# ...

# %%
final.to_csv("IPL AUCTION 2024 DATASET.csv")
